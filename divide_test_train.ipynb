# %%
import pandas as pd
data = pd.read_csv('C:\\Users\\scsi_public\\Desktop\\intern\\traintest.csv', engine = 'python', encoding = "cp949")
data
# Out:
#                  filename   width  height class    xmin   ymin    xmax   ymax  \
# 0         A001_A7X_04.jpg  1288.0   966.0    균열   838.0  873.0   928.0  964.0
# 1         A001_A7X_04.jpg  1288.0   966.0    균열   920.0  787.0  1024.0  863.0
# 2         A001_A7X_04.jpg  1288.0   966.0    균열  1010.0  718.0  1075.0  789.0
# 3         A001_A7X_04.jpg  1288.0   966.0    균열  1077.0  675.0  1130.0  723.0
# 4         A001_A7X_04.jpg  1288.0   966.0    균열  1131.0  618.0  1191.0  673.0
# ...                   ...     ...     ...   ...     ...    ...     ...    ...
# 45735     B437_A6X_14.jpg  1288.0   966.0    균열    14.0    1.0    79.0  311.0
# 45736  B437_A6X_14.jpg 개수     NaN     NaN   NaN     NaN    NaN     NaN    NaN
# 45737     B438_B6X_10.jpg  1288.0   966.0    오염    12.0    7.0  1285.0  962.0
# 45738  B438_B6X_10.jpg 개수     NaN     NaN   NaN     NaN    NaN     NaN    NaN
# 45739               전체 개수     NaN     NaN   NaN     NaN    NaN     NaN    NaN
#
#         flag
# 0       test
# ...

# %%
crack, contamination, whitening, scaling, spalling, leackage, rebar_exposure = 0, 0, 0, 0, 0, 0, 0

# %%
n = 0
for i in range(0,45739):
    if data['class'].iloc[i] == '균열': crack += 1
    elif data['class'].iloc[i] == '오염': contamination += 1
    elif data['class'].iloc[i] == '백화': whitening += 1
    elif data['class'].iloc[i] == '박리': scaling += 1
    elif data['class'].iloc[i] == '박락': spalling += 1
    elif data['class'].iloc[i] == '누수': leackage += 1
    elif data['class'].iloc[i] == '철근': rebar_exposure += 1
    else: 
        k = data['flag'].iloc[i]
        k = int(k)
        n += k
        
print( f'crack, contamination, whitening, scaling, spalling, leackage, rebar_exposure : {crack}, {contamination}, {whitening}, {scaling}, {spalling}, {leackage}, {rebar_exposure} ')
# Out:
# crack, contamination, whitening, scaling, spalling, leackage, rebar_exposure : 35281, 1498, 1045, 3481, 516, 798, 213

# %%
#철근
import random
i = 0
count_rebar_test, count_rebar_train = 0, 0
count_leak_test, count_leak_train = 0, 0
count_con_test, count_con_train = 0, 0
count_spal_test, count_spal_train = 0, 0
count_scal_test, count_scal_train = 0, 0
count_cra_test, count_cra_train = 0, 0
count_whi_test, count_whi_train = 0, 0
while i < 45739:
    if (data['class'].iloc[i] != '철근'): i += 1
    else:
            for  j in range(i, 45739):
                if data['flag'].iloc[j] == 'test': continue                    
                elif data['flag'].iloc[j] == 'train': continue
                elif data['flag'].iloc[j] == 'Test': continue
                elif data['flag'].iloc[j] == 'Train': continue
                else:
                    k = data['flag'].iloc[j]
                    k = int(k)
                    i = j+1
                    casno = random.randrange(1, 4)
                    if casno == 1:
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Test'
                            if data['class'].iloc[n] == '철근': count_rebar_test += 1
                            elif data['class'].iloc[n] == '누수': count_leak_test += 1
                            elif data['class'].iloc[n] == '오염': count_con_test += 1
                            elif data['class'].iloc[n] == '박락': count_spal_test += 1
                            elif data['class'].iloc[n] == '박리': count_scal_test += 1
                            elif data['class'].iloc[n] == '백화': count_whi_test += 1
                            elif data['class'].iloc[n] == '균열': count_cra_test += 1
                    else:
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Train'
                            if data['class'].iloc[n] == '철근': count_rebar_train += 1
                            elif data['class'].iloc[n] == '누수': count_leak_train += 1
                            elif data['class'].iloc[n] == '오염': count_con_train += 1
                            elif data['class'].iloc[n] == '박락': count_spal_train += 1
                            elif data['class'].iloc[n] == '박리': count_scal_train += 1
                            elif data['class'].iloc[n] == '백화': count_whi_train += 1
                            elif data['class'].iloc[n] == '균열': count_cra_train += 1
                    break
    
print(count_rebar_test, count_rebar_train)
# Out:
# C:\Users\scsi_public\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# 68 145

# %%
#박락
import random
i = 0
count_rebar_test, count_rebar_train = 0, 0
count_leak_test, count_leak_train = 0, 0
count_con_test, count_con_train = 0, 0
count_spal_test, count_spal_train = 0, 0
count_scal_test, count_scal_train = 0, 0
count_cra_test, count_cra_train = 0, 0
count_whi_test, count_whi_train = 0, 0
while i < 45740:
    if (data['class'].iloc[i] == '박락'):
            for  j in range(i, 45740):
                if data['flag'].iloc[j] == 'test': continue                    
                elif data['flag'].iloc[j] == 'train': continue
                elif data['flag'].iloc[j] == 'Test': 
                    continue
                elif data['flag'].iloc[j] == 'Train':
                    continue
                else:
                    k = data['flag'].iloc[j]
                    k = int(k)
                    i = j
                    casno = random.randrange(1, 4)
                    if (casno == 1) :
                       
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Test'
                            if data['class'].iloc[n] == '철근': count_rebar_test += 1
                            elif data['class'].iloc[n] == '누수': count_leak_test += 1
                            elif data['class'].iloc[n] == '오염': count_con_test += 1
                            elif data['class'].iloc[n] == '박락': count_spal_test += 1
                            elif data['class'].iloc[n] == '박리': count_scal_test += 1
                            elif data['class'].iloc[n] == '백화': count_whi_test += 1
                            elif data['class'].iloc[n] == '균열': count_cra_test += 1
                    else:
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Train'
                            if data['class'].iloc[n] == '철근': count_rebar_train += 1
                            elif data['class'].iloc[n] == '누수': count_leak_train += 1
                            elif data['class'].iloc[n] == '오염': count_con_train += 1
                            elif data['class'].iloc[n] == '박락': count_spal_train += 1
                            elif data['class'].iloc[n] == '박리': count_scal_train += 1
                            elif data['class'].iloc[n] == '백화': count_whi_train += 1
                            elif data['class'].iloc[n] == '균열': count_cra_train += 1
                    break
    else : i += 1
print(count_spal_test, count_spal_train)
# Out:
# 154 362

# %%
#누수
import random
i = 0
count_rebar_test, count_rebar_train = 0, 0
count_leak_test, count_leak_train = 0, 0
count_con_test, count_con_train = 0, 0
count_spal_test, count_spal_train = 0, 0
count_scal_test, count_scal_train = 0, 0
count_cra_test, count_cra_train = 0, 0
count_whi_test, count_whi_train = 0, 0
while i < 45740:
    if (data['class'].iloc[i] == '누수'):
            for  j in range(i, 45740):
                if data['flag'].iloc[j] == 'test': continue                    
                elif data['flag'].iloc[j] == 'train': continue
                elif data['flag'].iloc[j] == 'Test':
                    continue
                elif data['flag'].iloc[j] == 'Train':
                    continue
                else:
                    k = data['flag'].iloc[j]
                    k = int(k)
                    i = j
                    casno = random.randrange(1, 4)
                    if (casno == 1) :
                        
                        for n in range(j-k, j):                            
                            data['flag'].iloc[n] = 'Test'
                            if data['class'].iloc[n] == '철근': count_rebar_test += 1
                            elif data['class'].iloc[n] == '누수': count_leak_test += 1
                            elif data['class'].iloc[n] == '오염': count_con_test += 1
                            elif data['class'].iloc[n] == '박락': count_spal_test += 1
                            elif data['class'].iloc[n] == '박리': count_scal_test += 1
                            elif data['class'].iloc[n] == '백화': count_whi_test += 1
                            elif data['class'].iloc[n] == '균열': count_cra_test += 1
                    else:
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Train'
                            if data['class'].iloc[n] == '철근': count_rebar_train += 1
                            elif data['class'].iloc[n] == '누수': count_leak_train += 1
                            elif data['class'].iloc[n] == '오염': count_con_train += 1
                            elif data['class'].iloc[n] == '박락': count_spal_train += 1
                            elif data['class'].iloc[n] == '박리': count_scal_train += 1
                            elif data['class'].iloc[n] == '백화': count_whi_train += 1
                            elif data['class'].iloc[n] == '균열': count_cra_train += 1
                    break
    else : i += 1
print(count_leak_test, count_leak_train)
# Out:
# 258 540

# %%
#백화
import random
i = 0
count_rebar_test, count_rebar_train = 0, 0
count_leak_test, count_leak_train = 0, 0
count_con_test, count_con_train = 0, 0
count_spal_test, count_spal_train = 0, 0
count_scal_test, count_scal_train = 0, 0
count_cra_test, count_cra_train = 0, 0
count_whi_test, count_whi_train = 0, 0
while i < 45740:
    if (data['class'].iloc[i] == '백화'):
            for  j in range(i, 45740):
                if data['flag'].iloc[j] == 'test': continue                    
                elif data['flag'].iloc[j] == 'train': continue
                elif data['flag'].iloc[j] == 'Test':
                    continue
                elif data['flag'].iloc[j] == 'Train':
                    continue
                else:
                    k = data['flag'].iloc[j]
                    k = int(k)
                    i = j
                    casno = random.randrange(1,4)
                    if (casno == 1):
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Test'
                            if data['class'].iloc[n] == '철근': count_rebar_test += 1
                            elif data['class'].iloc[n] == '누수': count_leak_test += 1
                            elif data['class'].iloc[n] == '오염': count_con_test += 1
                            elif data['class'].iloc[n] == '박락': count_spal_test += 1
                            elif data['class'].iloc[n] == '박리': count_scal_test += 1
                            elif data['class'].iloc[n] == '백화': count_whi_test += 1
                            elif data['class'].iloc[n] == '균열': count_cra_test += 1
                    else:
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Train'
                            if data['class'].iloc[n] == '철근': count_rebar_train += 1
                            elif data['class'].iloc[n] == '누수': count_leak_train += 1
                            elif data['class'].iloc[n] == '오염': count_con_train += 1
                            elif data['class'].iloc[n] == '박락': count_spal_train += 1
                            elif data['class'].iloc[n] == '박리': count_scal_train += 1
                            elif data['class'].iloc[n] == '백화': count_whi_train += 1
                            elif data['class'].iloc[n] == '균열': count_cra_train += 1
                    break
    else : i += 1
print(count_whi_test, count_whi_train)
# Out:
# 311 734

# %%
#오염
import random
i = 0
count_rebar_test, count_rebar_train = 0, 0
count_leak_test, count_leak_train = 0, 0
count_con_test, count_con_train = 0, 0
count_spal_test, count_spal_train = 0, 0
count_scal_test, count_scal_train = 0, 0
count_cra_test, count_cra_train = 0, 0
count_whi_test, count_whi_train = 0, 0
while i < 45740:
    if (data['class'].iloc[i] == '오염'):
            for  j in range(i, 45740):
                if data['flag'].iloc[j] == 'test': continue                    
                elif data['flag'].iloc[j] == 'train': continue
                elif data['flag'].iloc[j] == 'Test':
                    continue
                elif data['flag'].iloc[j] == 'Train':
                    continue
                else:
                    k = data['flag'].iloc[j]
                    k = int(k)
                    i = j
                    casno = random.randrange(1, 4)
                    if (casno == 1):
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Test'
                            if data['class'].iloc[n] == '철근': count_rebar_test += 1
                            elif data['class'].iloc[n] == '누수': count_leak_test += 1
                            elif data['class'].iloc[n] == '오염': count_con_test += 1
                            elif data['class'].iloc[n] == '박락': count_spal_test += 1
                            elif data['class'].iloc[n] == '박리': count_scal_test += 1
                            elif data['class'].iloc[n] == '백화': count_whi_test += 1
                            elif data['class'].iloc[n] == '균열': count_cra_test += 1
                    else:
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Train'
                            if data['class'].iloc[n] == '철근': count_rebar_train += 1
                            elif data['class'].iloc[n] == '누수': count_leak_train += 1
                            elif data['class'].iloc[n] == '오염': count_con_train += 1
                            elif data['class'].iloc[n] == '박락': count_spal_train += 1
                            elif data['class'].iloc[n] == '박리': count_scal_train += 1
                            elif data['class'].iloc[n] == '백화': count_whi_train += 1
                            elif data['class'].iloc[n] == '균열': count_cra_train += 1
                    break
    else : i += 1
print(count_con_test, count_con_train)
# Out:
# 457 1041

# %%
#박리
import random
i = 0
count_rebar_test, count_rebar_train = 0, 0
count_leak_test, count_leak_train = 0, 0
count_con_test, count_con_train = 0, 0
count_spal_test, count_spal_train = 0, 0
count_scal_test, count_scal_train = 0, 0
count_cra_test, count_cra_train = 0, 0
count_whi_test, count_whi_train = 0, 0
while i < 45740:
    if (data['class'].iloc[i] == '박리'):
            for  j in range(i, 45740):
                if data['flag'].iloc[j] == 'test': continue                    
                elif data['flag'].iloc[j] == 'train': continue
                elif data['flag'].iloc[j] == 'Test':
                    continue
                elif data['flag'].iloc[j] == 'Train':
                    continue
                else:
                    k = data['flag'].iloc[j]
                    k = int(k)
                    i = j
                    casno = random.randrange(1, 4)
                    if (casno == 1):
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Test'
                            if data['class'].iloc[n] == '철근': count_rebar_test += 1
                            elif data['class'].iloc[n] == '누수': count_leak_test += 1
                            elif data['class'].iloc[n] == '오염': count_con_test += 1
                            elif data['class'].iloc[n] == '박락': count_spal_test += 1
                            elif data['class'].iloc[n] == '박리': count_scal_test += 1
                            elif data['class'].iloc[n] == '백화': count_whi_test += 1
                            elif data['class'].iloc[n] == '균열': count_cra_test += 1
                    else:
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Train'
                            if data['class'].iloc[n] == '철근': count_rebar_train += 1
                            elif data['class'].iloc[n] == '누수': count_leak_train += 1
                            elif data['class'].iloc[n] == '오염': count_con_train += 1
                            elif data['class'].iloc[n] == '박락': count_spal_train += 1
                            elif data['class'].iloc[n] == '박리': count_scal_train += 1
                            elif data['class'].iloc[n] == '백화': count_whi_train += 1
                            elif data['class'].iloc[n] == '균열': count_cra_train += 1
                    break
    else : i += 1
print(count_scal_test, count_scal_train)
# Out:
# 1047 2434

# %%
#균열
import random
i = 0
count_rebar_test, count_rebar_train = 0, 0
count_leak_test, count_leak_train = 0, 0
count_con_test, count_con_train = 0, 0
count_spal_test, count_spal_train = 0, 0
count_scal_test, count_scal_train = 0, 0
count_cra_test, count_cra_train = 0, 0
count_whi_test, count_whi_train = 0, 0
while i < 45740:
    if (data['class'].iloc[i] == '균열'):
            for  j in range(i, 45740):
                if data['flag'].iloc[j] == 'test': continue                    
                elif data['flag'].iloc[j] == 'train': continue
                elif data['flag'].iloc[j] == 'Test':
                    continue
                elif data['flag'].iloc[j] == 'Train':
                    continue
                else:
                    k = data['flag'].iloc[j]
                    k = int(k)
                    i = j
                    casno = random.randrange(1, 11)
                    if (casno == 1) or (casno == 2) or (casno == 3):
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Test'
                            if data['class'].iloc[n] == '균열': count_cra_test += 1
                            elif data['class'].iloc[n] == '누수': count_leak_test += 1
                            elif data['class'].iloc[n] == '오염': count_con_test += 1
                            elif data['class'].iloc[n] == '박락': count_spal_test += 1
                            elif data['class'].iloc[n] == '박리': count_scal_test += 1
                            elif data['class'].iloc[n] == '백화': count_whi_test += 1
                            elif data['class'].iloc[n] == '철근': count_rebar_test += 1
                    else:
                        
                        for n in range(j-k, j):
                            data['flag'].iloc[n] = 'Train'
                            if data['class'].iloc[n] == '균열': count_cra_train += 1
                            elif data['class'].iloc[n] == '누수': count_leak_train += 1
                            elif data['class'].iloc[n] == '오염': count_con_train += 1
                            elif data['class'].iloc[n] == '박락': count_spal_train += 1
                            elif data['class'].iloc[n] == '박리': count_scal_train += 1
                            elif data['class'].iloc[n] == '백화': count_whi_train += 1
                            elif data['class'].iloc[n] == '철근': count_rebar_train += 1
                    break
    else : i += 1
print(count_cra_test, count_cra_train)
# Out:
# 10950 24331

# %%
data
# Out:
#                  filename   width  height class    xmin   ymin    xmax   ymax  \
# 0         A001_A7X_04.jpg  1288.0   966.0    균열   838.0  873.0   928.0  964.0
# 1         A001_A7X_04.jpg  1288.0   966.0    균열   920.0  787.0  1024.0  863.0
# 2         A001_A7X_04.jpg  1288.0   966.0    균열  1010.0  718.0  1075.0  789.0
# 3         A001_A7X_04.jpg  1288.0   966.0    균열  1077.0  675.0  1130.0  723.0
# 4         A001_A7X_04.jpg  1288.0   966.0    균열  1131.0  618.0  1191.0  673.0
# ...                   ...     ...     ...   ...     ...    ...     ...    ...
# 45735     B437_A6X_14.jpg  1288.0   966.0    균열    14.0    1.0    79.0  311.0
# 45736  B437_A6X_14.jpg 개수     NaN     NaN   NaN     NaN    NaN     NaN    NaN
# 45737     B438_B6X_10.jpg  1288.0   966.0    오염    12.0    7.0  1285.0  962.0
# 45738  B438_B6X_10.jpg 개수     NaN     NaN   NaN     NaN    NaN     NaN    NaN
# 45739               전체 개수     NaN     NaN   NaN     NaN    NaN     NaN    NaN
#
#         flag
# 0      Train
# ...

# %%
crack_test, contamination_test, whitening_test, scaling_test, spalling_test, leackage_test, rebar_exposure_test = 0, 0, 0, 0, 0, 0 ,0
crack_train, contamination_train, whitening_train, scaling_train, spalling_train, leackage_train, rebar_exposure_train = 0, 0, 0, 0, 0, 0, 0
for i in range(0,45740):
    if data['class'].iloc[i] == '균열': 
        if data['flag'].iloc[i] == 'Test': crack_test += 1
        else : crack_train += 1
    elif data['class'].iloc[i] == '오염':
        if data['flag'].iloc[i] == 'Test' : contamination_test +=1
        else : contamination_train += 1
    elif data['class'].iloc[i] == '백화':
        if data['flag'].iloc[i] == 'Test': whitening_test += 1
        else : whitening_train += 1
    elif data['class'].iloc[i] == '박리':
        if data['flag'].iloc[i] == 'Test': scaling_test += 1
        else : scaling_train += 1
    elif data['class'].iloc[i] == '박락':
        if data['flag'].iloc[i] == 'Test': spalling_test += 1
        else : spalling_train += 1
    elif data['class'].iloc[i] == '누수':
        if data['flag'].iloc[i] == 'Test': leackage_test += 1
        else : leackage_train += 1
    elif data['class'].iloc[i] == '철근':
        if data['flag'].iloc[i] == 'Test': rebar_exposure_test += 1
        else : rebar_exposure_train += 1
print( f' test crack, contamination, whitening, scaling, spalling, leackage, rebar_exposure : {crack_test}, {contamination_test}, {whitening_test}, {scaling_test}, {spalling_test}, {leackage_test}, {rebar_exposure_test} ')
print( f' train crack, contamination, whitening, scaling, spalling, leackage, rebar_exposure : {crack_train}, {contamination_train}, {whitening_train}, {scaling_train}, {spalling_train}, {leackage_train}, {rebar_exposure_train} ')
# Out:
#  test crack, contamination, whitening, scaling, spalling, leackage, rebar_exposure : 10950, 549, 343, 1074, 159, 245, 68
#  train crack, contamination, whitening, scaling, spalling, leackage, rebar_exposure : 24331, 949, 702, 2407, 357, 553, 145

# %%
test, train = 0, 0
for i in range(0,45740):
    if data['flag'].iloc[i] == 'Test': test += 1
    elif data['flag'].iloc[i] == 'Train': train += 1

    
        
print(f'test train : {test}, {train}')
# Out:
# test train : 13388, 29444

# %%
data.to_csv("C:\\Users\\scsi_public\\Desktop\\intern\\testtrainrandom.csv",  index = False, encoding = 'cp949')
